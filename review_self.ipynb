# %% [markdown]
# ### 파이썬
# 1. 식별자
# 2. 인코딩 선언
# 3. 주석
# 4. 변수
# 5. 정수, 소수, 복소수, 부울, 문자형
# 6. 연산자
# 7. 비교연산자
# 8. 논리연산자
# 9. 복합연산자
# 10. 기타연산자
# 11. 연산자 우선순위
# 12. 형변환
# 13. 시퀀스 자료형
# 14. set, dictionary, tuple

# %% [markdown]
# 1. 조건문
# 2. Conditional Expression
# 3. while 문
# 4. for 문
# 5. enumerate
# 6. dictionary 반복문 사용하기
# 7. break, continue, else

# %% [markdown]
# 1. 함수, 매개변수
# 2. 함수 return
# 3. 함수 인자 기본값 설정
# 4. 키워드 인자
# 5. 가변 인자 리스트
# 6. 정의되지 않은 인자들 처리하기
# 7. 선언할때 ** 의미와 호출 할 때 **
#  - 선언때는 인자를 딕셔너리로 받겠다는 선언
#  - 호출할때는 여러 인자를 딕셔너리로 넣겠다는 선언
# 8. Namespace 스코프

# %% [markdown]
# 1. 재귀함수
# 2. 문자열 메소드
#  - capitalize()
#  - title()
#  - upper()
#  - lower()
#  - swapcase()
#  - join(iterable)
#  - replace(old, new, count)
#  - strip(없앨문자)
#  - find()
#  - index()
#  - split()
# 3. 리스트
#  - append()
#  - extend(iterable)
#  - insert(i,x)
#  - remove()
#  - pop()
#  - index()
#  - count()
#  - sort()
#  - reverse()
#  - clear()
#  - List Comprehension
# 4. 딕셔너리
#  - pop()
#  - update()
#  - get()
#  - Dictionary comprehension
# 5. 정리
#  - map(function, iterable)
#  - zip(iterable)
#  - filter(function, iterable)
# 6. 세트
#  - add()
#  - update()
#  - remove()
#  - discard()
#  - pop()
# 7. 모듈활용
#  - import
#  - from 모듈명 import 어트리뷰트
#  - from 모듈명 import *
#  - from 모듈명 import 어트리뷰트 as
# 8. 숫자모듈
#  - math.ceil()
#  - math.floor()
#  - math.trunc()
#  - math.copysign(x,y)
#  - math.fabs()
#  - math.factorial()
#  - math.fmod(x,y)
#  - math.fsum(iterable)
#  - math.modf()
#  - math.pow()
#  - math.sqrt()
#  - math.exp()
# 9. random
# 10. datetime

# %% [markdown]
# 1. Errors and Exceptions
#  - SyntaxError
#  - ZeroDivisionError
#  - NameError
#  - TypeError
#  - ValueError
#  - IndexError
#  - KeyError
#  - ModuleNotFoundError
#  - ImportError
#  - KeyboardInterrupt
# 2. 예외처리
#  - try except
# 3. 에러 문구 처리
#  - try
#  - except
#  - else
#  - finally
#  - default
# 4. 예외 발생시키기
#  - raise
#  - assert()
# 5. 클래스 및 인스턴스
#  - 클래스
#  - 인스턴스 객체
#  - self
#  - 클래스 인스턴스 간 이름공간
#  - 생성자 / 소멸자
#  - 클래스 변수 / 인스턴스 변수
#  - 정적 메서드 / 클래스 메서드
#  - 상속
#  - super()
#  - 메소드 오버라이딩
#  - 상속관계에서의 이름공간(인스턴스, 자식클래스, 부모클래스, 전역)
