# %%
! pip install --upgrade pip
! pip install pytorch-forecasting==0.10.3
! pip install pytorch_lightning==1.9.0
! pip install pyarrow==11.0.0
! pip install tensorboard==2.12.0
# ! pip install torch==1.12.1
# !pip install --upgrade sagemaker==2.118.0
# ! pip install boto3 --upgrade
# ! pip install botocore --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: pip in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (23.0.1)
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: pytorch-forecasting==0.10.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (0.10.3)
# Requirement already satisfied: pytorch-lightning<2.0.0,>=1.2.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pytorch-forecasting==0.10.3) (1.9.0)
# Requirement already satisfied: scipy<2.0,>=1.8 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pytorch-forecasting==0.10.3) (1.9.3)
# Requirement already satisfied: pandas<2.0.0,>=1.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pytorch-forecasting==0.10.3) (1.5.1)
# Requirement already satisfied: statsmodels in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pytorch-forecasting==0.10.3) (0.13.2)
# Requirement already satisfied: scikit-learn<1.2,>=0.24 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pytorch-forecasting==0.10.3) (1.1.3)
# Requirement already satisfied: optuna<3.0.0,>=2.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pytorch-forecasting==0.10.3) (2.10.1)
# Requirement already satisfied: matplotlib in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pytorch-forecasting==0.10.3) (3.6.1)
# Requirement already satisfied: torch<2.0,>=1.7 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pytorch-forecasting==0.10.3) (1.12.1)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from optuna<3.0.0,>=2.3.0->pytorch-forecasting==0.10.3) (1.22.4)
# Requirement already satisfied: cliff in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from optuna<3.0.0,>=2.3.0->pytorch-forecasting==0.10.3) (4.2.0)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from optuna<3.0.0,>=2.3.0->pytorch-forecasting==0.10.3) (21.3)
# Requirement already satisfied: alembic in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from optuna<3.0.0,>=2.3.0->pytorch-forecasting==0.10.3) (1.9.4)
# Requirement already satisfied: colorlog in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from optuna<3.0.0,>=2.3.0->pytorch-forecasting==0.10.3) (6.7.0)
# Requirement already satisfied: tqdm in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from optuna<3.0.0,>=2.3.0->pytorch-forecasting==0.10.3) (4.64.1)
# Requirement already satisfied: PyYAML in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from optuna<3.0.0,>=2.3.0->pytorch-forecasting==0.10.3) (5.4.1)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from optuna<3.0.0,>=2.3.0->pytorch-forecasting==0.10.3) (1.4.42)
# Requirement already satisfied: cmaes>=0.8.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from optuna<3.0.0,>=2.3.0->pytorch-forecasting==0.10.3) (0.9.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pandas<2.0.0,>=1.3.0->pytorch-forecasting==0.10.3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pandas<2.0.0,>=1.3.0->pytorch-forecasting==0.10.3) (2022.5)
# Requirement already satisfied: torchmetrics>=0.7.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting==0.10.3) (0.11.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting==0.10.3) (4.4.0)
# Requirement already satisfied: lightning-utilities>=0.4.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting==0.10.3) (0.7.1)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting==0.10.3) (2021.11.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from scikit-learn<1.2,>=0.24->pytorch-forecasting==0.10.3) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from scikit-learn<1.2,>=0.24->pytorch-forecasting==0.10.3) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib->pytorch-forecasting==0.10.3) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib->pytorch-forecasting==0.10.3) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib->pytorch-forecasting==0.10.3) (1.0.6)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib->pytorch-forecasting==0.10.3) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib->pytorch-forecasting==0.10.3) (4.38.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib->pytorch-forecasting==0.10.3) (9.2.0)
# Requirement already satisfied: patsy>=0.5.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from statsmodels->pytorch-forecasting==0.10.3) (0.5.3)
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting==0.10.3) (2.28.1)
# Requirement already satisfied: aiohttp in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting==0.10.3) (3.8.3)
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from patsy>=0.5.2->statsmodels->pytorch-forecasting==0.10.3) (1.16.0)
# Requirement already satisfied: greenlet!=0.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sqlalchemy>=1.1.0->optuna<3.0.0,>=2.3.0->pytorch-forecasting==0.10.3) (1.1.3.post0)
# Requirement already satisfied: Mako in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from alembic->optuna<3.0.0,>=2.3.0->pytorch-forecasting==0.10.3) (1.2.4)
# Requirement already satisfied: stevedore>=2.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from cliff->optuna<3.0.0,>=2.3.0->pytorch-forecasting==0.10.3) (5.0.0)
# Requirement already satisfied: autopage>=0.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from cliff->optuna<3.0.0,>=2.3.0->pytorch-forecasting==0.10.3) (0.5.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from cliff->optuna<3.0.0,>=2.3.0->pytorch-forecasting==0.10.3) (4.13.0)
# Requirement already satisfied: PrettyTable>=0.7.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from cliff->optuna<3.0.0,>=2.3.0->pytorch-forecasting==0.10.3) (3.6.0)
# Requirement already satisfied: cmd2>=1.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from cliff->optuna<3.0.0,>=2.3.0->pytorch-forecasting==0.10.3) (2.4.3)
# Requirement already satisfied: pyperclip>=1.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from cmd2>=1.0.0->cliff->optuna<3.0.0,>=2.3.0->pytorch-forecasting==0.10.3) (1.8.2)
# Requirement already satisfied: wcwidth>=0.1.7 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from cmd2>=1.0.0->cliff->optuna<3.0.0,>=2.3.0->pytorch-forecasting==0.10.3) (0.2.5)
# Requirement already satisfied: attrs>=16.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from cmd2>=1.0.0->cliff->optuna<3.0.0,>=2.3.0->pytorch-forecasting==0.10.3) (22.1.0)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from importlib-metadata>=4.4->cliff->optuna<3.0.0,>=2.3.0->pytorch-forecasting==0.10.3) (3.10.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from stevedore>=2.0.1->cliff->optuna<3.0.0,>=2.3.0->pytorch-forecasting==0.10.3) (5.11.1)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from aiohttp->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting==0.10.3) (2.1.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from aiohttp->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting==0.10.3) (1.8.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from aiohttp->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting==0.10.3) (1.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from aiohttp->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting==0.10.3) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from aiohttp->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting==0.10.3) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from aiohttp->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting==0.10.3) (1.3.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from Mako->alembic->optuna<3.0.0,>=2.3.0->pytorch-forecasting==0.10.3) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting==0.10.3) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting==0.10.3) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting==0.10.3) (3.4)
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: pytorch_lightning==1.9.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (1.9.0)
# Requirement already satisfied: lightning-utilities>=0.4.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pytorch_lightning==1.9.0) (0.7.1)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pytorch_lightning==1.9.0) (2021.11.1)
# Requirement already satisfied: torchmetrics>=0.7.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pytorch_lightning==1.9.0) (0.11.3)
# Requirement already satisfied: numpy>=1.17.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pytorch_lightning==1.9.0) (1.22.4)
# Requirement already satisfied: torch>=1.10.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pytorch_lightning==1.9.0) (1.12.1)
# Requirement already satisfied: PyYAML>=5.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pytorch_lightning==1.9.0) (5.4.1)
# Requirement already satisfied: tqdm>=4.57.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pytorch_lightning==1.9.0) (4.64.1)
# Requirement already satisfied: packaging>=17.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pytorch_lightning==1.9.0) (21.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pytorch_lightning==1.9.0) (4.4.0)
# Requirement already satisfied: aiohttp in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from fsspec[http]>2021.06.0->pytorch_lightning==1.9.0) (3.8.3)
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from fsspec[http]>2021.06.0->pytorch_lightning==1.9.0) (2.28.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from packaging>=17.1->pytorch_lightning==1.9.0) (3.0.9)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from aiohttp->fsspec[http]>2021.06.0->pytorch_lightning==1.9.0) (1.8.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from aiohttp->fsspec[http]>2021.06.0->pytorch_lightning==1.9.0) (22.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from aiohttp->fsspec[http]>2021.06.0->pytorch_lightning==1.9.0) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from aiohttp->fsspec[http]>2021.06.0->pytorch_lightning==1.9.0) (4.0.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from aiohttp->fsspec[http]>2021.06.0->pytorch_lightning==1.9.0) (2.1.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from aiohttp->fsspec[http]>2021.06.0->pytorch_lightning==1.9.0) (1.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from aiohttp->fsspec[http]>2021.06.0->pytorch_lightning==1.9.0) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests->fsspec[http]>2021.06.0->pytorch_lightning==1.9.0) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests->fsspec[http]>2021.06.0->pytorch_lightning==1.9.0) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests->fsspec[http]>2021.06.0->pytorch_lightning==1.9.0) (2022.9.24)
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: pyarrow in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (11.0.0)
# Requirement already satisfied: numpy>=1.16.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pyarrow) (1.22.4)
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Collecting tensorboard
#   Downloading tensorboard-2.12.0-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 68.0 MB/s eta 0:00:00:00:010:01
# Requirement already satisfied: requests<3,>=2.21.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from tensorboard) (2.28.1)
# Requirement already satisfied: wheel>=0.26 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from tensorboard) (0.37.1)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.4.1-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.3/93.3 kB 19.2 MB/s eta 0:00:00
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: numpy>=1.12.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from tensorboard) (1.22.4)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.0-py3-none-manylinux2014_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 89.3 MB/s eta 0:00:00:00:0100:01
# Collecting absl-py>=0.4
#   Downloading absl_py-1.4.0-py3-none-any.whl (126 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.5/126.5 kB 17.2 MB/s eta 0:00:00
# Collecting grpcio>=1.48.2
#   Downloading grpcio-1.51.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 88.1 MB/s eta 0:00:00:00:01
# Requirement already satisfied: setuptools>=41.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from tensorboard) (65.5.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from tensorboard) (2.2.2)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 76.3 MB/s eta 0:00:00
# Requirement already satisfied: protobuf>=3.19.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from tensorboard) (3.20.3)
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.16.2-py2.py3-none-any.whl (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.2/177.2 kB 29.0 MB/s eta 0:00:00
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.3.0-py3-none-any.whl (9.3 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 29.5 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.9.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard) (4.7.2)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard) (0.4.8)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 29.2 MB/s eta 0:00:00
# Installing collected packages: tensorboard-plugin-wit, tensorboard-data-server, pyasn1-modules, oauthlib, markdown, grpcio, cachetools, absl-py, requests-oauthlib, google-auth, google-auth-oauthlib, tensorboard
# Successfully installed absl-py-1.4.0 cachetools-5.3.0 google-auth-2.16.2 google-auth-oauthlib-0.4.6 grpcio-1.51.3 markdown-3.4.1 oauthlib-3.2.2 pyasn1-modules-0.2.8 requests-oauthlib-1.3.1 tensorboard-2.12.0 tensorboard-data-server-0.7.0 tensorboard-plugin-wit-1.8.1

# %%
# %%sh
# pip list | pytorch-forecasting
# pip list | grep torch
# pip list | grep sagemaker
# pip list | grep boto
# pip list | grep pyarrow
# pip list | grep tensorboard
# Out:
# pytorch-forecasting           0.10.3
# pytorch-lightning             1.9.0
# torch                         1.12.1
# torchmetrics                  0.11.3
# sagemaker                     2.118.0
# sagemaker-experiments         0.1.42
# sagemaker-pyspark             1.4.5
# aiobotocore                   2.0.1
# boto3                         1.26.44
# botocore                      1.29.65
# pyarrow                       11.0.0
# tensorboard                   2.12.0
# tensorboard-data-server       0.7.0
# tensorboard-plugin-wit        1.8.1
# sh: line 1: pytorch-forecasting: command not found
# ERROR: Pipe to stdout was broken
# Exception ignored in: <_io.TextIOWrapper name='<stdout>' mode='w' encoding='utf-8'>
# BrokenPipeError: [Errno 32] Broken pipe

# %%
! bash local_mode_setup.sh
# Out:
# nvidia-docker2 already installed. We are good to go!
# Redirecting to /bin/systemctl stop docker.service
# Warning: Stopping docker.service, but it can still be activated by:
#   docker.socket
# Redirecting to /bin/systemctl start docker.service
# Error: inet address is expected rather than "dev".
# SageMaker instance routing for Docker is ok. We are good to go!
